# %%
using LinearAlgebra
using Plots
using Interact
# Out:
# HTML{String}("<script>\n// Immediately-invoked-function-expression to avoid global variables.\n(function() {\n    var warning_div = document.getElementById(\"webio-warning-17501692189585667746\");\n    var hide = function () {\n        var script = document.getElementById(\"webio-setup-13667692502443597841\");\n        var parent = script && script.parentElement;\n        var grandparent = parent && parent.parentElement;\n        if (grandparent) {\n            grandparent.style.display = \"none\";\n        }\n        warning_div.style.display = \"none\";\n    };\n    if (typeof Jupyter !== \"undefined\") {\n        console.log(\"WebIO detected Jupyter notebook environment.\");\n        // Jupyter notebook.\n        var extensions = (\n            Jupyter\n            && Jupyter.notebook.config.data\n            && Jupyter.notebook.config.data.load_extensions\n        );\n        if (extensions && extensions[\"webio-jupyter-notebook\"]) {\n            // Extension already loaded.\n            console.log(\"Jupyter WebIO nbextension detected; not loading ad-hoc.\");\n            hide();\n            return;\n        }\n    } else if (window.location.pathname.includes(\"/lab\")) {\n        // Guessing JupyterLa\n        console.log(\"Jupyter Lab detected; make sure the @webio/jupyter-lab-provider labextension is installed.\");\n        hide();\n        return;\n    }\n})();\n\n</script>\n<p\n    id=\"webio-warning-17501692189585667746\"\n    class=\"output_text output_stderr\"\n    style=\"padding: 1em; font-weight: bold;\"\n>\n    Unable to load WebIO. Please make sure WebIO works for your Jupyter client.\n    For troubleshooting, please see <a href=\"https://juliagizmos.github.io/WebIO.jl/latest/providers/ijulia/\">\n    the WebIO/IJulia documentation</a>.\n    <!-- TODO: link to installation docs. -->\n</p>\n")

# %% [markdown]
# # Subspaces

# %%
X = -10:0.1:10;
f = [X X];
plot(f[:,1], f[:,2], framestyle = :origin)

# %%
XY_grid_tuple = Iterators.product(-1.:0.5:1, -1.:0.5:1);
XY_grid = vec(collect.(XY_grid_tuple));
X = [];
Y = [];
for i in 1:length(XY_grid)
    X = [X;XY_grid[i][1]];
    Y = [Y;XY_grid[i][2]];
end
XY_grid
# Out:
# 25-element Vector{Vector{Float64}}:
#  [-1.0, -1.0]
#  [-0.5, -1.0]
#  [0.0, -1.0]
#  [0.5, -1.0]
#  [1.0, -1.0]
#  [-1.0, -0.5]
#  [-0.5, -0.5]
#  [0.0, -0.5]
#  [0.5, -0.5]
#  [1.0, -0.5]
#  [-1.0, 0.0]
#  [-0.5, 0.0]
#  [0.0, 0.0]
#  [0.5, 0.0]
#  [1.0, 0.0]
#  [-1.0, 0.5]
#  [-0.5, 0.5]
#  [0.0, 0.5]
#  [0.5, 0.5]
#  [1.0, 0.5]
#  [-1.0, 1.0]
#  [-0.5, 1.0]
#  [0.0, 1.0]
#  [0.5, 1.0]
#  [1.0, 1.0]

# %%
### EDIT VALUES ###
a = 1;
b = 1;
c = 0;
### EDIT VALUES ###
f = [a.*X b.*Y a.*X.+b.*Y.+c]
surface(f[:,1],f[:,2],f[:,3], framestyle = :origin)

# %% [markdown]
# # QR Factorization

# %%
Q = [1 0 0; 0 1/sqrt(2) -1/sqrt(2); 0 1/sqrt(2) 1/sqrt(2)];
R = [1 0 2; 0 sqrt(2) 2*sqrt(2); 0 0 sqrt(2)];
Q*R
# Out:
# 3×3 Matrix{Float64}:
#  1.0  0.0  2.0
#  0.0  1.0  1.0
#  0.0  1.0  3.0

# %%
A = [1 0 2; 0 1 1; 0 1 3];
Q = [1 0 0; 0 1/sqrt(2) -1/sqrt(2); 0 1/sqrt(2) 1/sqrt(2)];
R = Q'*A
Q*R
# Out:
# 3×3 Matrix{Float64}:
#  1.0  0.0  2.0
#  0.0  1.0  1.0
#  0.0  1.0  3.0
